# %% [markdown]
# # In-Class Exercises 3
#
# > **Note:**
# >
# > Please commit every time you solve one of the exercises. An example commit message
# > could be `"Solution to question 1"`. Feel free to commit more than once per
# > exercise if solving it requires multiple complicated steps.

# %% [markdown]
# ## Python
#
# ---
# ### Question 1
#
# Write a function that takes an integer and check whether it is a prime number, i.e. if
# called with a prime number it should return True, else it should return False.
#
# Use a brute force approach with a for loop and do not think about smart algorithms.
#
# Reminder: A prime number is a natural number that has exactly two natural divisors
# (1 and itself). By this definition, 1 is not a prime number but 2 is.
#
# Use this function to create a list of all prime numbers smaller than 10

# %% [markdown]
# ---
# ### Question 2
#
# Write a function that takes a list of keys and a list of values and creates a
# dictionary containing the key value pairs.

# %% [markdown]
# ---
# ### Question 3
#
# The previous question has one very short solution:
#
# ```python
# def combine_keys_and_values(keys, values):
#     return dict(zip(keys, values, strict=True))
#
# ```
#
# Regarding this solution, discuss the following statements in your group
#
# 1. The shortest solution is always the best. It reduces complexity because there is less
# code to read.
# 2. If the function body is a one-liner, you don't need to define a function
# 3. If the function body is a one-liner, you should use a very abbreviated function name like `combkv` instead of `combine_keys_and_value` so using a function still saves you
# typing

# %% [markdown]
# ---
# ### Question 4
#
# **Understanding side effects of functions**
#
# Consider the following code snippet:

# %%
def power_utility_loss_aversion(z_list, gamma, lambda_):
    """Calculate the power utility function with loss aversion.

    Args:
        z_list (list): Monetary quantities
        gamma (float): Curvature parameter
        lambda_ (float): Loss aversion parameter.

    Returns:
        list: Utility evaluations.
    """
    out = z_list
    for i, z in enumerate(z_list):
        if z >= 0:
            out[i] = z ** (1 - gamma)
        else:
            out[i] = -lambda_ * (-z) ** (1 - gamma)

    return out


# Define the characteristics of the individual.
power_coefficient = 0.5
loss_aversion_coefficient = 2.0

# Define the monetary payoffs.
payoffs = [500, -550]

# Compute the utility values
evaluations = power_utility_loss_aversion(
    z_list=payoffs,
    gamma=power_coefficient,
    lambda_=loss_aversion_coefficient,
)

# Print the utility values to the screen.
print(evaluations)

# Goal: Understand what happened here.
print(payoffs)

# %% [markdown]
# The screencasts so far have covered everything you need to know. However, some of the concepts here are difficult. This is why we use the [Python Tutor](http://pythontutor.com/) to look a bit deeper into the code execution:
#
# 1. Run the code snippet above through [http://pythontutor.com/](http://pythontutor.com/)
# 1. Make sure to understand what happens **in each step**. Before executing the next step, predict what will happen to the variables in memory and why. If your model of the Python language is off, discuss with your group members.
# 1. Describe precisely what side effect the function has. Which variable is affected by the side effect and how?
# 1. Describe a scenario in which this side effect can lead to incorrect results.
#
#
# Be prepared to explain your group's answers in the plenary session.

# %% [markdown]
# ## Git for collaboration
#
# ---
# ### Question 5 (Stampede)
#
# You might know the greatest lovers of all music history: Tristan and Isolde. For the
# purposes of this course, they have an appropriately nerdy way of stating their love,
# namely by a little dialogue in a sequence diagram (embedded in a Markdown document via
# [Mermaid](https://mermaid-js.github.io/mermaid/#/)).
#
# You will do so now in your group. Please work individually for tasks a. to e. — that is,
# please do **not coordinate** at all on the tasks, except designating one person to start
# with a. for your group. Of course, you should help each other with technical problems.
#
# 1. Please create / go to the repository for your team by clicking on
#    [this link](https://classroom.github.com/a/SX2pMQnu).
#
# 2. Clone the repository to your machine.
#
# 3. Open `dialogue.md` in VS Code.
#
# 4. Do you notice anything about the text? Each one of you, feel free to fix the wrong
# word, change entire sentences, add more to the dialogue -- whatever you feel like!
#
# 5. Once you are done, make a new commit and push it to the central repository
# changes.
#
# 6. Pushing to the remote repository will not work for some of you. Discuss among you why
#    that is the case. Try to understand the error message that the team members see.

# %% [markdown]
# ---
# ### Question 6 (Learning about merge conflicts and fixing them)
#
# - Explain to each other what merge conflicts are. Be sure that everyone in the team
#   now understands the problem.
#
# - Move forward. Fix the conflicts.
#
# - **Continue with the next question only after every group member has completed the
#   following two tasks**
#
#   1. Fixed a merge conflict and
#   2. Managed to push his or her changes up to the GitHub repository.

# %% [markdown]
# ---
# ### Question 7 (Changes in different parts of a file)
#
# - Make sure everybody has a clean repository and is up-to-date with the GitHub
#     repository (`git pull`, `git status`)
#
# - Pick two group members to change `dialogue.md`
#
#   - One person adds the following to the top of `dialogue.md`:
#
#     ```markdown
#     # Introduction to the love story
#
#     A Cornish knight once met an Irish princess.
#     ```
#
#   - One person adds the following to the bottom of `dialogue.md`:
#
#     ```markdown
#     # The end
#
#     Tristan and Isolde are dead.
#     ```
#
#   (Feel free to change the language ;-))
#
# - The first person who is ready pushes his / her changes to the central repository
#
# - The other person goes through the same process as in Question 6.
#
# - Do you see a merge conflict? Why or why not? Discuss!

# %% [markdown]
# ---
# ### Question 8 (Visualising branches)
#
# - The command line is **not** great for visualisations.
#
# - So let us look for an extension to VS Code
#
# - How to go about that?
#
#   1. Search the web for what you want to do. Here: "vs code visualize git branches".
#   1. Git Graph for VS Code will pop up.
#   1. Check the download statistics whether it is actually used a lot. (> 10.000 unless
#      very exotic tool)
#   1. Follow the installation steps you see on the website (copy to clipboard, hit
#      ctrl+p, paste)
#
# - Use Git Graph to visualize the history of your "Tristan & Isolde" commits.
#
#     **Important: You need to open the entire `tristan-and-isolde-xxx` directory in VS
#     Code, not just a single file**
#
# - Take a screenshot, the group with the craziest history will be the team of the day!

# %% [markdown]
# ---
# ### Question 9 (Branches and sensible workflows)
#
# - Are merge conflicts a problem caused by Git? Or by your workflow? Could they be
#   avoided by other collaboration tools that do not require working on the exact same
#   copy in real time (e.g., VS Code + Live Share, Overleaf, Google Docs, ...)? Discuss
#   in your group.
# - In Task 3, you have already merged two branches. In particular, you have merged the
#   `main` branch on GitHub into the `main` branch on your local machine. To gain a
#   deeper understanding of the power of making explicit branches, please have a look
#   [here](https://www.atlassian.com/git/tutorials/using-branches)
#
# <!--
# - Think about the remaining assignments. What would be a good workflow for
#     collaboration in your group? Think about making productive use of Git and working
#     asynchronously. That is, do not stop at saying "We will meet on Zoom and use Live
#     Share all the time.".
# -->
